# %%
import pandas as pd

df = pd.read_csv('KAG_energydata_complete.csv')
missing = df.isnull().sum().sum()
missing_ratio = (missing / (df.shape[0] * df.shape[1])) * 100
duplicate = df.duplicated().sum()
total = df.shape[0]

print("결측치:", missing)
print("결측치 비율:", missing_ratio)
print("중복:", duplicate)
# Out:
# 결측치: 0
# 결측치 비율: 0.0
# 중복: 0
